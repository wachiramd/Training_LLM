# %% [markdown]
# ## Load the tokenizer

# %%
import wandb
import sys
sys.path.append('..')

# %%
from minbpe import BasicTokenizer

tokenizer = BasicTokenizer()
tokenizer.load(model_file="../output/tokenizer/my_tokenizer.model")


def get_vocab_size(tokenizer: BasicTokenizer) -> int:
    vocab = tokenizer.vocab
    special_tokens = tokenizer.special_tokens

    return len(vocab) + len(special_tokens)

# %% [markdown]
# ## Create the model

# %%
import torch
torch.manual_seed(3647)

# %%
from transformer.model import GPTLanguageModel

block_size = 256
n_embd = 512
n_head = 8
n_layer = 4
dropout = 0.2
batch_size = 64
vocab_size = get_vocab_size(tokenizer)
device = 'mps' if torch.backends.mps.is_available() else 'cpu'

model = GPTLanguageModel(
    vocab_size=vocab_size,
    block_size=block_size,
    n_embd=n_embd,
    n_head=n_head,
    n_layer=n_layer,
    dropout=dropout,
    device=device
).to(device)
# model = torch.compile(model)

print(sum(p.numel() for p in model.parameters())/1e6, 'M parameters')
print(device)
# Out:
# 13.793288 M parameters
# mps

# %% [markdown]
# ## Data preparation

# %% [markdown]
# ### 1. Load the data

# %%
with open("../output/combined_text.txt", "r", encoding='utf-8') as f:
    text_sequence = f.read()

encoded_text_sequence = tokenizer.encode(text_sequence)
len(encoded_text_sequence)
# Out:
# 93679

# %% [markdown]
# ### 2. Split it into train and test

# %%
data = torch.tensor(encoded_text_sequence, dtype=torch.long)
split_index = int(0.9 * len(data))
train_data = data[:split_index]
val_data = data[split_index:]

# %% [markdown]
# ### 3. Data loader

# %%
from typing import Tuple
from torch.utils.data import Dataset, DataLoader


class TextDataset(Dataset):
    def __init__(self, data: torch.Tensor, block_size: int) -> None:
        if len(data) <= block_size:
            raise ValueError(
                f"The length of the data ({len(data)}) must be greater than the block_size ({block_size})."
            )

        self.data = data
        self.block_size = block_size

    def __len__(self) -> int:
        return len(self.data) - self.block_size

    def __getitem__(self, index: int) -> Tuple[torch.Tensor, torch.Tensor]:
        x = self.data[index : index + self.block_size]
        y = self.data[index + 1 : index + self.block_size + 1]
        return x, y


def get_dataloaders(
    train_data: torch.Tensor,
    val_data: torch.Tensor,
    block_size: int,
    batch_size: int,
    device: torch.device,
) -> Tuple[DataLoader, DataLoader]:
    train_dataset = TextDataset(train_data.to(device), block_size)
    val_dataset = TextDataset(val_data.to(device), block_size)

    train_loader = DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True,
    )
    val_loader = DataLoader(
        val_dataset,
        batch_size=batch_size,
        shuffle=False,
    )

    return train_loader, val_loader

# %%
train_loader, val_loader = get_dataloaders(
    train_data=train_data,
    val_data=val_data,
    block_size=block_size,
    batch_size=batch_size,
    device=device,
)
x, y = next(iter(train_loader))
x.shape, y.shape
# Out:
# (torch.Size([64, 256]), torch.Size([64, 256]))

# %% [markdown]
# ### 4. Training

# %%
from typing import Dict


@torch.no_grad()
def estimate_loss(
    model: torch.nn.Module,
    train_loader: DataLoader,
    val_loader: DataLoader,
    eval_iters: int
) -> Dict[str, float]:
    output = {}
    model.eval()

    for split, loader in [('train', train_loader), ('val', val_loader)]:
        losses = torch.zeros(eval_iters)
        for i, (x, y) in enumerate(loader):
            if i >= eval_iters:
                break
            with torch.no_grad():
                _, loss = model(x, y)
            losses[i] = loss.item()
        output[split] = losses.mean().item()

    model.train()
    return output

# %%
def save_checkpoint(
    model: GPTLanguageModel,
    optimizer: torch.optim.Optimizer,
    epoch: int,
    loss: float,
    file_path: str = "checkpoint.pth"
) -> None:
    checkpoint = {
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'loss': loss
    }
    torch.save(checkpoint, file_path)

# %%
max_iters = 5
eval_interval = 100
eval_iters = 20
learning_rate = 5e-5

optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
train_loader, val_loader = get_dataloaders(
    train_data=train_data,
    val_data=val_data,
    block_size=block_size,
    batch_size=batch_size,
    device=device
)

wandb.init(project="dan-llm-training")
train_losses = []
val_losses = []

for iteration in range(max_iters):
    for batch_idx, (x_batch, y_batch) in enumerate(train_loader):
        # Evaluation
        if batch_idx % eval_interval == 0 or batch_idx == len(train_loader) - 1:
            losses = estimate_loss(
                model=model,
                train_loader=train_loader,
                val_loader=val_loader,
                eval_iters=min(eval_iters, len(val_loader))
            )
            train_losses.append(losses['train'])
            val_losses.append(losses['val'])
            wandb.log({'train_loss': losses['train'], 'val_loss': losses['val']})

            print(
                f"iteration {iteration} / step {batch_idx}: "
                f"train loss {losses['train']:.4f}, "
                f"val loss {losses['val']:.4f}"
            )

        # Training step
        logits, loss = model(x_batch, y_batch)
        optimizer.zero_grad(set_to_none=True)
        loss.backward()
        optimizer.step()

    # Save checkpoint
    save_checkpoint(
        model=model,
        optimizer=optimizer,
        epoch=iteration,
        loss=loss.item(),
        file_path=f"../output/pre_training/run_4/checkpoint_{iteration}.pth"
    )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[46], line 15
#       6 optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
#       7 train_loader, val_loader = get_dataloaders(
#       8     train_data=train_data,
#       9     val_data=val_data,
#    (...)     12     device=device
#      13 )
# ---> 15 wandb.init(project="dan-llm-training")
#      16 train_losses = []
#      17 val_losses = []
#
# File /opt/anaconda3/envs/torenv/lib/python3.13/site-packages/wandb/sdk/wandb_init.py:1515, in init(entity, project, dir, id, name, notes, tags, config, config_exclude_keys, config_include_keys, allow_val_change, group, job_type, mode, force, reinit, resume, resume_from, fork_from, save_code, tensorboard, sync_tensorboard, monitor_gym, settings, anonymous)
#    1511 wl = wandb_setup.singleton()
#    1513 wi = _WandbInit(wl, init_telemetry)
# -> 1515 wi.maybe_login(init_settings)
#    1516 run_settings, show_warnings = wi.make_run_settings(init_settings)
#    1518 if isinstance(run_settings.reinit, bool):
#
# File /opt/anaconda3/envs/torenv/lib/python3.13/site-packages/wandb/sdk/wandb_init.py:192, in _WandbInit.maybe_login(self, init_settings)
#     189 if run_settings._noop or run_settings._offline:
#     190     return
# --> 192 wandb_login._login(
#     193     host=run_settings.base_url,
#     194     force=run_settings.force,
#     195     key=run_settings.api_key,
#     196     # Do not save an explicitly provided API key to .netrc.
#     197     update_api_key=run_settings.api_key is None,
#     198     _silent=run_settings.quiet or run_settings.silent,
#     199 )
#
# File /opt/anaconda3/envs/torenv/lib/python3.13/site-packages/wandb/sdk/wandb_login.py:346, in _login(key, relogin, host, force, timeout, verify, referrer, update_api_key, no_oidc, _silent)
#     343     wlogin.update_session(key, status=ApiKeyStatus.VALID)
#     345     if not _silent:
# --> 346         wlogin._print_logged_in_message()
#     348     return True, key
#     350 # See if there already is a key in settings. This is true if WANDB_API_KEY
#     351 # was set or login() already happened.
#
# File /opt/anaconda3/envs/torenv/lib/python3.13/site-packages/wandb/sdk/wandb_login.py:176, in _WandbLogin._print_logged_in_message(self)
#     174 def _print_logged_in_message(self) -> None:
#     175     """Prints a message telling the user they are logged in."""
# --> 176     username = self._wandb_setup._get_username()
#     178     if username:
#     179         host_str = (
#     180             f" to {click.style(self._settings.base_url, fg='green')}"
#     181             if self._settings.base_url
#     182             else ""
#     183         )
#
# File /opt/anaconda3/envs/torenv/lib/python3.13/site-packages/wandb/sdk/wandb_setup.py:329, in _WandbSetup._get_username(self)
#     327 if self._settings and self._settings._offline:
#     328     return None
# --> 329 return self.viewer.get("username")
#
# File /opt/anaconda3/envs/torenv/lib/python3.13/site-packages/wandb/sdk/wandb_setup.py:344, in _WandbSetup.viewer(self)
#     341 if self._server is None:
#     342     self._server = server.Server(settings=self.settings)
# --> 344 return self._server.viewer
#
# File /opt/anaconda3/envs/torenv/lib/python3.13/site-packages/wandb/sdk/lib/server.py:57, in Server.viewer(self)
#      44 """Returns information about the currently authenticated user.
#      45
#      46 If the API key is valid, the following is returned:
#    (...)     54 an empty dict is returned.
#      55 """
#      56 if not self._viewer and not self._settings._offline:
# ---> 57     self.query_with_timeout()
#      59 return self._viewer
#
# File /opt/anaconda3/envs/torenv/lib/python3.13/site-packages/wandb/sdk/lib/server.py:35, in Server.query_with_timeout(self, timeout)
#      33 except Exception:
#      34     return
# ---> 35 if viewer_thread.is_alive():
#      36     # this is likely a DNS hang
#      37     return
#      38 # TODO(jhr): should we kill the thread?
#
# File /opt/anaconda3/envs/torenv/lib/python3.13/threading.py:1145, in Thread.is_alive(self)
#    1137 """Return whether the thread is alive.
#    1138
#    1139 This method returns True just before the run() method starts until just
#    (...)   1142
#    1143 """
#    1144 assert self._initialized, "Thread.__init__() not called"
# -> 1145 return self._started.is_set() and not self._handle.is_done()
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(train_losses, label="Train Loss", marker='o')
plt.plot(val_losses, label="Validation Loss", marker='o')
plt.xlabel("Evaluation Step")
plt.ylabel("Loss")
plt.title("Training and Validation Loss Over Time")
plt.legend()
plt.grid()
plt.show()

# %%
input_tokens = tokenizer.encode("Good morning Daniel")
input_tokens = torch.tensor(
    input_tokens, dtype=torch.long).unsqueeze(0).to(device)

model.eval()
with torch.no_grad():
    output = model.generate(input_tokens=input_tokens, max_new_tokens=100)

print(tokenizer.decode(output[0].tolist()))
